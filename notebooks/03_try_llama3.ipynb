# %%
import torch
from datasets import load_dataset
from transformers import (
    BitsAndBytesConfig, 
    AutoModelForCausalLM, 
    AutoTokenizer, 
    Trainer, 
    TrainingArguments, 
    DataCollatorForSeq2Seq
)
from peft import LoraConfig, PeftModel

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline

model_name = "meta-llama/Llama-3.2-1B-Instruct"

# Can't run this on CPU
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    # quantization_config=bnb_config,
    use_cache=False,
    device_map="auto",
)

text_generator = pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=1024
)


def get_generated_output(prompt):
    output = text_generator(prompt)
    return output[0]["generated_text"]


print(get_generated_output("Who is Carl Jung?"))
# Out:
# Device set to use mps
# Who is Carl Jung? Carl Gustav Jung was a Swiss psychiatrist and psychoanalyst who founded analytical psychology, a school of thought that focuses on the process of individuation, the integration of the unconscious, and the development of the whole person. Jung is perhaps most famous for his concept of the collective unconscious, which posits that certain universal symbols and archetypes are shared across cultures and time.
# Jung's work was heavily influenced by Sigmund Freud, his former mentor, but he also developed his own theories and ideas, which diverged from Freud's psychoanalytic approach. Jung's ideas have had a profound impact on modern psychology, philosophy, and spirituality. He is considered one of the most influential thinkers of the 20th century.
# Some of Jung's key ideas include:
# 1. The concept of the collective unconscious: Jung believed that certain universal symbols and archetypes are shared across cultures and time, and that these symbols are part of a shared psychological heritage.
# 2. The process of individuation: Jung saw individuation as the process of integrating the opposites (e.g. conscious and unconscious, rational and emotional) to become a whole and balanced individual.
# 3. The concept of archetypes: Jung believed that certain universal symbols and images (archetypes) are present in the collective unconscious and that they play a role in shaping human experience.
# 4. The concept of the anima and animus: Jung believed that men and women have a shared unconscious, with the anima (the feminine aspect of a man) and animus (the masculine aspect of a woman) playing a crucial role in the process of individuation.
# 5. The concept of the shadow: Jung believed that the shadow refers to the repressed or hidden aspects of the personality, which can include qualities that are considered unacceptable or taboo.
# 6. The concept of the process of synchronicity: Jung believed that events in the world are connected by a process of synchronicity, where events seem to be connected by a hidden pattern or thread.
# 7. The concept of the collective shadow: Jung believed that the collective shadow is a shared aspect of the unconscious, and that it plays a role in shaping human experience.
#
# Some of Jung's notable books include:
#
# * "The Collected Works of C.G. Jung" (published posthumously)
# * "The Archetypes and the Collective Unconscious" (published posthumously)
# * "Man and His Symbols" (published posthumously)
# * "The Psychology of the Unconscious" (published posthumously)
#
# Some of Jung's notable figures include:
#
# * Sigmund Freud
# * Carl Rogers
# * Rollo May
# * Joseph Campbell
# * Marion Woodman
#
# Jung's ideas have been influential in a wide range of fields, including psychology, philosophy, spirituality, and art. His concepts of the collective unconscious, archetypes, and the process of individuation have been widely adopted and have shaped the development of modern thought.

# %%
print(get_generated_output("Can you interprete dreams in the way Carl Jung did?"))
# Out:
# Can you interprete dreams in the way Carl Jung did??
# Carl Jung, a Swiss psychiatrist and psychoanalyst, developed the concept of oneirocriticism, which is the study of dreams. He believed that dreams are a way for the unconscious mind to communicate with the conscious mind, and that they can provide insight into the unconscious thoughts, desires, and unresolved conflicts that are hidden from conscious awareness.
# Here are some key aspects of Carl Jung's oneirocriticism:
#
# 1. **The Collective Unconscious**: Jung believed that there is a shared reservoir of archetypes and experiences that are common to all humans, and that these experiences are reflected in dreams. He called this collective unconscious a shared psychological reservoir.
# 2. **The Process of Individuation**: Jung saw dreams as a way for the unconscious mind to work through the process of individuation, which involves integrating the opposites (e.g. conscious and unconscious, rational and emotional) to become a whole and balanced individual.
# 3. **The Role of the Shadow**: Jung believed that dreams often reveal the repressed or hidden aspects of the self, known as the shadow. He saw the shadow as a source of creativity, innovation, and emotional depth.
# 4. **The Process of Active Imagination**: Jung developed the concept of active imagination, which involves using the dream as a catalyst for self-reflection and personal growth. He believed that the process of active imagination could help individuals tap into their unconscious mind and access hidden knowledge and insights.
# 5. **The Integration of the Personal Unconscious**: Jung saw dreams as a way for the personal unconscious to communicate with the collective unconscious, and for the conscious mind to integrate the insights and experiences of the personal unconscious.
#
# Some of the key techniques used by Carl Jung to interpret dreams include:
#
# 1. **Dream Analysis**: Jung used a systematic approach to analyze dreams, including the use of symbols, imagery, and emotions.
# 2. **Active Imagination**: Jung encouraged individuals to engage in active imagination, using the dream as a catalyst for self-reflection and personal growth.
# 3. **Journaling**: Jung believed that journaling could be a powerful tool for accessing the unconscious mind and exploring the hidden aspects of the self.
# 4. **Rituals and Symbolism**: Jung used rituals and symbolism to tap into the collective unconscious and access the hidden aspects of the self.
#
# Some of the key concepts that Jung developed in relation to dreams include:
#
# 1. **The Oneiric Symbol**: Jung saw the oneiric symbol as a universal symbol that is present in dreams across cultures and time.
# 2. **The Archetypal Symbol**: Jung believed that the archetypal symbol is a universal symbol that represents a specific archetype or concept.
# 3. **The Process of Symbolization**: Jung saw the process of symbolization as a way of accessing the hidden aspects of the self through the use of symbols and images.
#
# Overall, Carl Jung's oneirocriticism provides a rich and complex framework for understanding dreams and the unconscious mind. His work continues to inspire and influence the field of psychology and psychotherapy to this day.
